# %%
# -----------------------------------------------------------
# CELL 1: Load API Key and Connect to Database
# os, dotenv  → load the API key securely from .env file
# sqlite3     → connect to the Chinook database
# openai      → official Python client for the OpenAI API
# -----------------------------------------------------------

import os
import sqlite3
from dotenv import load_dotenv
from openai import OpenAI

# Load API key from .env file
load_dotenv()
client = OpenAI()

# Connect to Chinook database
conn = sqlite3.connect('../data/Chinook_Sqlite.sqlite')
cursor = conn.cursor()

print('API key loaded and database connected successfully!')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_4578/884873103.py in <cell line: 0>()
#      16
#      17 # Connect to Chinook database
# ---> 18 conn = sqlite3.connect('../data/Chinook_Sqlite.sqlite')
#      19 cursor = conn.cursor()
#      20
#
# OperationalError: unable to open database file

# %%
# -----------------------------------------------------------
# CELL 2: Load Schema String
# We re-run the schema extraction logic here so this notebook
# is self-contained and does not depend on running another
# notebook first. The schema_string is passed into the LLM
# prompt so the model knows what tables and columns exist.
# -----------------------------------------------------------

# Extract all table names
cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
tables = [row[0] for row in cursor.fetchall()]

# Extract columns for each table
schema = {}
for table in tables:
    cursor.execute(f'PRAGMA table_info({table})')
    columns = cursor.fetchall()
    schema[table] = [(col[1], col[2]) for col in columns]

# Format schema as a clean string for the LLM prompt
def format_schema_for_prompt(schema):
    schema_str = ''
    for table, columns in schema.items():
        schema_str += f'Table: {table}\n'
        for col_name, col_type in columns:
            schema_str += f'  - {col_name} ({col_type})\n'
        schema_str += '\n'
    return schema_str

schema_string = format_schema_for_prompt(schema)
print('Schema loaded successfully!')
print(f'Total tables: {len(schema)}')
# Out:
# Schema loaded successfully!
# Total tables: 11

# %%
# -----------------------------------------------------------
# CELL 3: Build the Prompt
# The prompt is the instruction we send to the LLM.
# It has 3 parts:
#   1. The database schema (what tables/columns exist)
#   2. Instructions (return only SQL, no explanation)
#   3. The user's question
# This is the core of prompt engineering for our project.
# -----------------------------------------------------------

def build_prompt(schema_string, user_question):
    prompt = f"""You are an expert SQL assistant.

You are given the following database schema:
{schema_string}

Write a valid SQLite SQL query to answer the following question:
{user_question}

Rules:
- Return ONLY the SQL query, nothing else
- Do not include any explanation or markdown
- Do not use ```sql or ``` in your response
- Make sure the query is valid SQLite syntax
"""
    return prompt

# Test the prompt with a sample question
test_question = "Which artist has the most albums?"
prompt = build_prompt(schema_string, test_question)
print('Prompt built successfully!')
print('---')
print(prompt)
# Out:
# Prompt built successfully!
# ---
# You are an expert SQL assistant.
#
# You are given the following database schema:
# Table: Album
#   - AlbumId (INTEGER)
#   - Title (NVARCHAR(160))
#   - ArtistId (INTEGER)
#
# Table: Artist
#   - ArtistId (INTEGER)
#   - Name (NVARCHAR(120))
#
# Table: Customer
#   - CustomerId (INTEGER)
#   - FirstName (NVARCHAR(40))
#   - LastName (NVARCHAR(20))
#   - Company (NVARCHAR(80))
#   - Address (NVARCHAR(70))
#   - City (NVARCHAR(40))
#   - State (NVARCHAR(40))
#   - Country (NVARCHAR(40))
#   - PostalCode (NVARCHAR(10))
#   - Phone (NVARCHAR(24))
#   - Fax (NVARCHAR(24))
#   - Email (NVARCHAR(60))
#   - SupportRepId (INTEGER)
#
# Table: Employee
#   - EmployeeId (INTEGER)
#   - LastName (NVARCHAR(20))
#   - FirstName (NVARCHAR(20))
#   - Title (NVARCHAR(30))
#   - ReportsTo (INTEGER)
#   - BirthDate (DATETIME)
#   - HireDate (DATETIME)
#   - Address (NVARCHAR(70))
#   - City (NVARCHAR(40))
#   - State (NVARCHAR(40))
#   - Country (NVARCHAR(40))
#   - PostalCode (NVARCHAR(10))
#   - Phone (NVARCHAR(24))
#   - Fax (NVARCHAR(24))
#   - Email (NVARCHAR(60))
#
# Table: Genre
#   - GenreId (INTEGER)
#   - Name (NVARCHAR(120))
#
# Table: Invoice
#   - InvoiceId (INTEGER)
#   - CustomerId (INTEGER)
#   - InvoiceDate (DATETIME)
#   - BillingAddress (NVARCHAR(70))
#   - BillingCity (NVARCHAR(40))
#   - BillingState (NVARCHAR(40))
#   - BillingCountry (NVARCHAR(40))
#   - BillingPostalCode (NVARCHAR(10))
#   - Total (NUMERIC(10,2))
#
# Table: InvoiceLine
#   - InvoiceLineId (INTEGER)
#   - InvoiceId (INTEGER)
#   - TrackId (INTEGER)
#   - UnitPrice (NUMERIC(10,2))
#   - Quantity (INTEGER)
#
# Table: MediaType
#   - MediaTypeId (INTEGER)
#   - Name (NVARCHAR(120))
#
# Table: Playlist
#   - PlaylistId (INTEGER)
#   - Name (NVARCHAR(120))
#
# Table: PlaylistTrack
#   - PlaylistId (INTEGER)
#   - TrackId (INTEGER)
#
# Table: Track
#   - TrackId (INTEGER)
#   - Name (NVARCHAR(200))
#   - AlbumId (INTEGER)
#   - MediaTypeId (INTEGER)
#   - GenreId (INTEGER)
#   - Composer (NVARCHAR(220))
#   - Milliseconds (INTEGER)
#   - Bytes (INTEGER)
#   - UnitPrice (NUMERIC(10,2))
#
#
#
# Write a valid SQLite SQL query to answer the following question:
# Which artist has the most albums?
#
# Rules:
# - Return ONLY the SQL query, nothing else
# - Do not include any explanation or markdown
# - Do not use ```sql or ``` in your response
# - Make sure the query is valid SQLite syntax

# %%
# -----------------------------------------------------------
# CELL 4: Send Prompt to LLM
# We send the prompt to GPT-4o-mini via the OpenAI API.
# The model reads the schema + question and returns a SQL query.
# We extract just the text content from the response.
# -----------------------------------------------------------

def get_sql_from_llm(prompt):
    response = client.chat.completions.create(
        model='gpt-4o-mini',
        messages=[
            {'role': 'system', 'content': 'You are an expert SQL assistant. Return only valid SQL queries.'},
            {'role': 'user', 'content': prompt}
        ],
        temperature=0  # temperature=0 means deterministic output (less creative, more precise)
    )
    # Extract the SQL text from the response
    sql_query = response.choices[0].message.content.strip()
    return sql_query

# Test with our sample question
sql_query = get_sql_from_llm(prompt)
print('SQL generated by LLM:')
print(sql_query)
# Out:
# SQL generated by LLM:
# SELECT Artist.Name, COUNT(Album.AlbumId) AS AlbumCount
# FROM Artist
# JOIN Album ON Artist.ArtistId = Album.ArtistId
# GROUP BY Artist.ArtistId
# ORDER BY AlbumCount DESC
# LIMIT 1;

# %%
# -----------------------------------------------------------
# CELL 5: Run SQL on the Database
# We execute the SQL query the LLM generated on the Chinook
# database and fetch the results.
# If the SQL is invalid, this will raise an error — we will
# handle that in the self-correction loop later.
# -----------------------------------------------------------

def run_sql(sql_query):
    cursor.execute(sql_query)
    results = cursor.fetchall()
    return results

# Run the SQL and print results
results = run_sql(sql_query)
print('Query results:')
for row in results:
    print(row)
# Out:
# Query results:
# ('Iron Maiden', 21)

# %%
# -----------------------------------------------------------
# CELL 6: Full End-to-End Pipeline
# This function combines all steps into one clean flow:
# question → prompt → LLM → SQL → database → result
# This is the core of our Text-to-SQL application.
# -----------------------------------------------------------

def text_to_sql_pipeline(user_question):
    print(f'Question: {user_question}')
    print('---')

    # Step 1: Build the prompt
    prompt = build_prompt(schema_string, user_question)

    # Step 2: Get SQL from LLM
    sql_query = get_sql_from_llm(prompt)
    print(f'Generated SQL: {sql_query}')
    print('---')

    # Step 3: Run SQL on database
    results = run_sql(sql_query)
    print(f'Results: {results}')
    return results

# Test with multiple questions
text_to_sql_pipeline("Which artist has the most albums?")
print()
text_to_sql_pipeline("What are the top 5 genres by number of tracks?")
print()
text_to_sql_pipeline("How many customers are from the USA?")
# Out:
# Question: Which artist has the most albums?
# ---
# Generated SQL: SELECT Artist.Name, COUNT(Album.AlbumId) AS AlbumCount
# FROM Artist
# JOIN Album ON Artist.ArtistId = Album.ArtistId
# GROUP BY Artist.ArtistId
# ORDER BY AlbumCount DESC
# LIMIT 1;
# ---
# Results: [('Iron Maiden', 21)]
#
# Question: What are the top 5 genres by number of tracks?
# ---
# Generated SQL: SELECT g.Name, COUNT(t.TrackId) AS TrackCount
# FROM Genre g
# JOIN Track t ON g.GenreId = t.GenreId
# GROUP BY g.GenreId
# ORDER BY TrackCount DESC
# LIMIT 5;
# ---
# Results: [('Rock', 1297), ('Latin', 579), ('Metal', 374), ('Alternative & Punk', 332), ('Jazz', 130)]
#
# Question: How many customers are from the USA?
# ---
# Generated SQL: SELECT COUNT(*) FROM Customer WHERE Country = 'USA';
# ---
# Results: [(13,)]
# [(13,)]

# %%
# -----------------------------------------------------------
# CELL 7: Build the Correction Prompt
# When SQL fails, we send a new prompt to the LLM containing:
#   1. The SQL that failed
#   2. The exact error message
#   3. The original question
#   4. The schema string so LLM knows correct table/column names
# The LLM uses this to understand what went wrong and fix it.
# -----------------------------------------------------------

def build_correction_prompt(user_question, failed_sql, error_message, schema_string):
    prompt = f"""The following SQL query failed when run on a SQLite database:

{failed_sql}

Error message:
{error_message}

Here is the correct database schema:
{schema_string}

Please fix the SQL query to correctly answer the following question:
{user_question}

Rules:
- Return ONLY the corrected SQL query, nothing else
- Do not include any explanation or markdown
- Do not use ```sql or ``` in your response
- Make sure the query is valid SQLite syntax
- Only use table and column names that exist in the schema above
"""
    return prompt

print('Correction prompt function defined successfully!')
# Out:
# Correction prompt function defined successfully!

# %%
# -----------------------------------------------------------
# CELL 8: Self-Correction Loop
# This function wraps run_sql() with retry logic:
#   - Try running the SQL
#   - If it fails, send the error back to the LLM
#   - Ask the LLM to fix and retry
#   - Limit to max_retries attempts to avoid infinite loops
# -----------------------------------------------------------

def run_sql_with_correction(user_question, sql_query, max_retries=3):
    attempt = 0

    while attempt < max_retries:
        try:
            # Try running the SQL
            cursor.execute(sql_query)
            results = cursor.fetchall()
            if attempt > 0:
                print(f'SQL succeeded on attempt {attempt + 1}')
            return results  # success — return results

        except Exception as error:
            attempt += 1
            print(f'Attempt {attempt} failed: {error}')

            if attempt >= max_retries:
                print('Max retries reached. Could not fix the SQL.')
                return None

            # Build correction prompt with schema and ask LLM to fix the SQL
            print('Asking LLM to fix the SQL...')
            correction_prompt = build_correction_prompt(user_question, sql_query, str(error), schema_string)
            sql_query = get_sql_from_llm(correction_prompt)
            print(f'Corrected SQL: {sql_query}')

print('Self-correction loop defined successfully!')
# Out:
# Self-correction loop defined successfully!

# %%
# -----------------------------------------------------------
# CELL 9: Test the Self-Correction Loop
# We intentionally pass a broken SQL query to test that
# the self-correction loop catches the error and fixes it.
# -----------------------------------------------------------

# Test with a deliberately broken SQL query
broken_sql = "SELECT * FROM NonExistentTable LIMIT 5"
test_question = "Which artist has the most albums?"

print('Testing self-correction loop with a broken SQL query...')
print('---')
results = run_sql_with_correction(test_question, broken_sql)
print(f'Final results: {results}')
# Out:
# Testing self-correction loop with a broken SQL query...
# ---
# Attempt 1 failed: no such table: NonExistentTable
# Asking LLM to fix the SQL...
# Corrected SQL: SELECT ArtistId, COUNT(AlbumId) AS AlbumCount FROM Album GROUP BY ArtistId ORDER BY AlbumCount DESC LIMIT 1
# SQL succeeded on attempt 2
# Final results: [(90, 21)]

# %%
# -----------------------------------------------------------
# CELL 10: Updated Full Pipeline with Self-Correction
# We replace run_sql() with run_sql_with_correction()
# so the full pipeline now automatically handles SQL errors.
# -----------------------------------------------------------

def text_to_sql_pipeline_v2(user_question):
    print(f'Question: {user_question}')
    print('---')

    # Step 1: Build the prompt
    prompt = build_prompt(schema_string, user_question)

    # Step 2: Get SQL from LLM
    sql_query = get_sql_from_llm(prompt)
    print(f'Generated SQL: {sql_query}')
    print('---')

    # Step 3: Run SQL with self-correction
    results = run_sql_with_correction(user_question, sql_query)
    print(f'Results: {results}')
    return results

# Evaluation Benchmark Questions

text_to_sql_pipeline_v2("How many customers are in the database?")
print()

text_to_sql_pipeline_v2("How many music genres are available?")
print()

text_to_sql_pipeline_v2("Which country has the most customers?")
print()

text_to_sql_pipeline_v2("Which artist has released the most albums?")
print()

text_to_sql_pipeline_v2("How many invoices are in the database?")
print()

text_to_sql_pipeline_v2("What are the five longest tracks?")
print()

text_to_sql_pipeline_v2("How many employees are in the database?")
print()

text_to_sql_pipeline_v2("List all customers who live in Brazil.")
print()

text_to_sql_pipeline_v2("Which employee supports the most customers?")
print()

text_to_sql_pipeline_v2("Which customer has spent the most money?")
print()

text_to_sql_pipeline_v2("Which music genre has generated the highest revenue?")
print()

text_to_sql_pipeline_v2("What is the average invoice total?")
print()

text_to_sql_pipeline_v2("Which billing country generated the highest sales?")
print()

text_to_sql_pipeline_v2("Which playlist contains the most tracks?")
print()

text_to_sql_pipeline_v2("Which media type contains the most tracks?")
print()

text_to_sql_pipeline_v2("Which artist has the most tracks?")
print()

text_to_sql_pipeline_v2("How many customers have never placed an order?")
print()

text_to_sql_pipeline_v2("Which country has the highest average invoice total?")
print()

text_to_sql_pipeline_v2("What are the top five countries by total sales revenue?")
print()

text_to_sql_pipeline_v2("Which customer placed the largest single order?")
print()
# Out:
# Question: How many customers are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Customer;
# ---
# Results: [(59,)]
#
# Question: How many music genres are available?
# ---
# Generated SQL: SELECT COUNT(*) FROM Genre;
# ---
# Results: [(25,)]
#
# Question: Which country has the most customers?
# ---
# Generated SQL: SELECT Country, COUNT(*) AS CustomerCount
# FROM Customer
# GROUP BY Country
# ORDER BY CustomerCount DESC
# LIMIT 1;
# ---
# Results: [('USA', 13)]
#
# Question: Which artist has released the most albums?
# ---
# Generated SQL: SELECT Artist.Name, COUNT(Album.AlbumId) AS AlbumCount
# FROM Artist
# JOIN Album ON Artist.ArtistId = Album.ArtistId
# GROUP BY Artist.ArtistId
# ORDER BY AlbumCount DESC
# LIMIT 1;
# ---
# Results: [('Iron Maiden', 21)]
#
# Question: How many invoices are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Invoice;
# ---
# Results: [(412,)]
#
# Question: What are the five longest tracks?
# ---
# Generated SQL: SELECT Name, Milliseconds
# FROM Track
# ORDER BY Milliseconds DESC
# LIMIT 5;
# ---
# Results: [('Occupation / Precipice', 5286953), ('Through a Looking Glass', 5088838), ('Greetings from Earth, Pt. 1', 2960293), ('The Man With Nine Lives', 2956998), ('Battlestar Galactica, Pt. 2', 2956081)]
#
# Question: How many employees are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Employee;
# ---
# Results: [(8,)]
#
# Question: List all customers who live in Brazil.
# ---
# Generated SQL: SELECT * FROM Customer WHERE Country = 'Brazil';
# ---
# Results: [(1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3), (10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4), (11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5), (12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3), (13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4)]
#
# Question: Which employee supports the most customers?
# ---
# Generated SQL: SELECT e.EmployeeId, e.FirstName, e.LastName, COUNT(c.CustomerId) AS CustomerCount
# FROM Employee e
# LEFT JOIN Customer c ON e.EmployeeId = c.SupportRepId
# GROUP BY e.EmployeeId
# ORDER BY CustomerCount DESC
# LIMIT 1;
# ---
# Results: [(3, 'Jane', 'Peacock', 21)]
#
# Question: Which customer has spent the most money?
# ---
# Generated SQL: SELECT CustomerId, SUM(Total) AS TotalSpent
# FROM Invoice
# GROUP BY CustomerId
# ORDER BY TotalSpent DESC
# LIMIT 1;
# ---
# Results: [(6, 49.620000000000005)]
#
# Question: Which music genre has generated the highest revenue?
# ---
# Generated SQL: SELECT g.Name, SUM(il.UnitPrice * il.Quantity) AS TotalRevenue
# FROM Genre g
# JOIN Track t ON g.GenreId = t.GenreId
# JOIN InvoiceLine il ON t.TrackId = il.TrackId
# JOIN Invoice i ON il.InvoiceId = i.InvoiceId
# GROUP BY g.GenreId
# ORDER BY TotalRevenue DESC
# LIMIT 1;
# ---
# Results: [('Rock', 826.6500000000061)]
#
# Question: What is the average invoice total?
# ---
# Generated SQL: SELECT AVG(Total) AS AverageInvoiceTotal FROM Invoice;
# ---
# Results: [(5.651941747572825,)]
#
# Question: Which billing country generated the highest sales?
# ---
# Generated SQL: SELECT BillingCountry, SUM(Total) AS TotalSales
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY TotalSales DESC
# LIMIT 1;
# ---
# Results: [('USA', 523.0600000000003)]
#
# Question: Which playlist contains the most tracks?
# ---
# Generated SQL: SELECT PlaylistId, COUNT(TrackId) AS TrackCount
# FROM PlaylistTrack
# GROUP BY PlaylistId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [(1, 3290)]
#
# Question: Which media type contains the most tracks?
# ---
# Generated SQL: SELECT MediaTypeId, COUNT(*) AS TrackCount
# FROM Track
# GROUP BY MediaTypeId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [(1, 3034)]
#
# Question: Which artist has the most tracks?
# ---
# Generated SQL: SELECT a.Name, COUNT(t.TrackId) AS TrackCount
# FROM Artist a
# JOIN Album al ON a.ArtistId = al.ArtistId
# JOIN Track t ON al.AlbumId = t.AlbumId
# GROUP BY a.ArtistId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [('Iron Maiden', 213)]
#
# Question: How many customers have never placed an order?
# ---
# Generated SQL: SELECT COUNT(*) AS CustomersWithoutOrders
# FROM Customer
# WHERE CustomerId NOT IN (SELECT DISTINCT CustomerId FROM Invoice);
# ---
# Results: [(0,)]
#
# Question: Which country has the highest average invoice total?
# ---
# Generated SQL: SELECT BillingCountry, AVG(Total) AS AverageTotal
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY AverageTotal DESC
# LIMIT 1;
# ---
# Results: [('Chile', 6.659999999999999)]
#
# Question: What are the top five countries by total sales revenue?
# ---
# Generated SQL: SELECT BillingCountry, SUM(Total) AS TotalRevenue
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY TotalRevenue DESC
# LIMIT 5;
# ---
# Results: [('USA', 523.0600000000003), ('Canada', 303.9599999999999), ('France', 195.09999999999994), ('Brazil', 190.09999999999997), ('Germany', 156.48)]
#
# Question: Which customer placed the largest single order?
# ---
# Generated SQL: SELECT Customer.FirstName, Customer.LastName, Invoice.Total
# FROM Invoice
# JOIN Customer ON Invoice.CustomerId = Customer.CustomerId
# ORDER BY Invoice.Total DESC
# LIMIT 1;
# ---
# Results: [('Helena', 'Holý', 25.86)]

# %%
# ----------------------------------------------------------
# CELL 11: Automatic Evaluation
# Compares pipeline output to expected answers
# ----------------------------------------------------------

#added a small delay between questions,that prevents hitting the RPM limit even after your RPD quota resets

import time

for question in benchmark_questions:
    text_to_sql_pipeline_v2(question)
    print()
    time.sleep(7)

benchmark_questions = [
    "How many customers are in the database?",
    "How many music genres are available?",
    "Which country has the most customers?",
    "Which artist has released the most albums?",
    "How many invoices are in the database?",
    "What are the five longest tracks?",
    "How many employees are in the database?",
    "List all customers who live in Brazil.",
    "Which employee supports the most customers?",
    "Which customer has spent the most money?",
    "Which music genre has generated the highest revenue?",
    "What is the average invoice total?",
    "Which billing country generated the highest sales?",
    "Which playlist contains the most tracks?",
    "Which media type contains the most tracks?",
    "Which artist has the most tracks?",
    "How many customers have never placed an order?",
    "Which country has the highest average invoice total?",
    "What are the top five countries by total sales revenue?",
    "Which customer placed the largest single order?"
]

expected_answers = [
    "59",
    "25",
    "USA",
    "Iron Maiden",
    "412",
    "Occupation / Precipice",
    "8",
    "Luís",
    "Jane Peacock",
    "49.62",
    "Rock",
    "5.65",
    "USA",
    "3290",
    "3034",
    "Iron Maiden",
    "0",
    "Chile",
    "Canada",
    "Helena"
]

correct = 0

print("=" * 70)
print("TEXT-TO-SQL PIPELINE EVALUATION")
print("=" * 70)

for i in range(len(benchmark_questions)):

    print(f"\nQuestion {i+1}")
    print(benchmark_questions[i])

    result = text_to_sql_pipeline_v2(benchmark_questions[i])

    if expected_answers[i].lower() in str(result).lower():
        print("PASS")
        correct += 1
    else:
        print("FAIL")
        print("Expected:", expected_answers[i])
        print("Returned:", result)

accuracy = (correct / len(benchmark_questions)) * 100

print("\n" + "=" * 70)
print(f"Correct Answers : {correct}/{len(benchmark_questions)}")
print(f"Accuracy        : {accuracy:.2f}%")
print("=" * 70)
# Out:
# Question: How many customers are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Customer;
# ---
# Results: [(59,)]
#
# Question: How many music genres are available?
# ---
# Generated SQL: SELECT COUNT(*) FROM Genre;
# ---
# Results: [(25,)]
#
# Question: Which country has the most customers?
# ---
# Generated SQL: SELECT Country, COUNT(*) AS CustomerCount
# FROM Customer
# GROUP BY Country
# ORDER BY CustomerCount DESC
# LIMIT 1;
# ---
# Results: [('USA', 13)]
#
# Question: Which artist has released the most albums?
# ---
# Generated SQL: SELECT Artist.Name, COUNT(Album.AlbumId) AS AlbumCount
# FROM Artist
# JOIN Album ON Artist.ArtistId = Album.ArtistId
# GROUP BY Artist.ArtistId
# ORDER BY AlbumCount DESC
# LIMIT 1;
# ---
# Results: [('Iron Maiden', 21)]
#
# Question: How many invoices are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Invoice;
# ---
# Results: [(412,)]
#
# Question: What are the five longest tracks?
# ---
# Generated SQL: SELECT Name, Milliseconds
# FROM Track
# ORDER BY Milliseconds DESC
# LIMIT 5;
# ---
# Results: [('Occupation / Precipice', 5286953), ('Through a Looking Glass', 5088838), ('Greetings from Earth, Pt. 1', 2960293), ('The Man With Nine Lives', 2956998), ('Battlestar Galactica, Pt. 2', 2956081)]
#
# Question: How many employees are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Employee;
# ---
# Results: [(8,)]
#
# Question: List all customers who live in Brazil.
# ---
# Generated SQL: SELECT * FROM Customer WHERE Country = 'Brazil';
# ---
# Results: [(1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3), (10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4), (11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5), (12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3), (13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4)]
#
# Question: Which employee supports the most customers?
# ---
# Generated SQL: SELECT e.EmployeeId, e.FirstName, e.LastName, COUNT(c.CustomerId) AS CustomerCount
# FROM Employee e
# LEFT JOIN Customer c ON e.EmployeeId = c.SupportRepId
# GROUP BY e.EmployeeId
# ORDER BY CustomerCount DESC
# LIMIT 1;
# ---
# Results: [(3, 'Jane', 'Peacock', 21)]
#
# Question: Which customer has spent the most money?
# ---
# Generated SQL: SELECT CustomerId, SUM(Total) AS TotalSpent
# FROM Invoice
# GROUP BY CustomerId
# ORDER BY TotalSpent DESC
# LIMIT 1;
# ---
# Results: [(6, 49.620000000000005)]
#
# Question: Which music genre has generated the highest revenue?
# ---
# Generated SQL: SELECT g.Name, SUM(il.UnitPrice * il.Quantity) AS Revenue
# FROM Genre g
# JOIN Track t ON g.GenreId = t.GenreId
# JOIN InvoiceLine il ON t.TrackId = il.TrackId
# GROUP BY g.GenreId
# ORDER BY Revenue DESC
# LIMIT 1;
# ---
# Results: [('Rock', 826.6500000000061)]
#
# Question: What is the average invoice total?
# ---
# Generated SQL: SELECT AVG(Total) AS AverageInvoiceTotal FROM Invoice;
# ---
# Results: [(5.651941747572825,)]
#
# Question: Which billing country generated the highest sales?
# ---
# Generated SQL: SELECT BillingCountry, SUM(Total) AS TotalSales
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY TotalSales DESC
# LIMIT 1;
# ---
# Results: [('USA', 523.0600000000003)]
#
# Question: Which playlist contains the most tracks?
# ---
# Generated SQL: SELECT PlaylistId, COUNT(TrackId) AS TrackCount
# FROM PlaylistTrack
# GROUP BY PlaylistId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [(1, 3290)]
#
# Question: Which media type contains the most tracks?
# ---
# Generated SQL: SELECT MediaTypeId, COUNT(*) AS TrackCount
# FROM Track
# GROUP BY MediaTypeId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [(1, 3034)]
#
# Question: Which artist has the most tracks?
# ---
# Generated SQL: SELECT a.Name, COUNT(t.TrackId) AS TrackCount
# FROM Artist a
# JOIN Album al ON a.ArtistId = al.ArtistId
# JOIN Track t ON al.AlbumId = t.AlbumId
# GROUP BY a.ArtistId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [('Iron Maiden', 213)]
#
# Question: How many customers have never placed an order?
# ---
# Generated SQL: SELECT COUNT(*) AS CustomersWithoutOrders
# FROM Customer
# WHERE CustomerId NOT IN (SELECT DISTINCT CustomerId FROM Invoice);
# ---
# Results: [(0,)]
#
# Question: Which country has the highest average invoice total?
# ---
# Generated SQL: SELECT BillingCountry, AVG(Total) AS AverageTotal
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY AverageTotal DESC
# LIMIT 1;
# ---
# Results: [('Chile', 6.659999999999999)]
#
# Question: What are the top five countries by total sales revenue?
# ---
# Generated SQL: SELECT BillingCountry, SUM(Total) AS TotalRevenue
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY TotalRevenue DESC
# LIMIT 5;
# ---
# Results: [('USA', 523.0600000000003), ('Canada', 303.9599999999999), ('France', 195.09999999999994), ('Brazil', 190.09999999999997), ('Germany', 156.48)]
#
# Question: Which customer placed the largest single order?
# ---
# Generated SQL: SELECT Customer.FirstName, Customer.LastName, Invoice.Total
# FROM Invoice
# JOIN Customer ON Invoice.CustomerId = Customer.CustomerId
# ORDER BY Invoice.Total DESC
# LIMIT 1;
# ---
# Results: [('Helena', 'Holý', 25.86)]
#
# ======================================================================
# TEXT-TO-SQL PIPELINE EVALUATION
# ======================================================================
#
# Question 1
# How many customers are in the database?
# Question: How many customers are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Customer;
# ---
# Results: [(59,)]
# PASS
#
# Question 2
# How many music genres are available?
# Question: How many music genres are available?
# ---
# Generated SQL: SELECT COUNT(*) FROM Genre;
# ---
# Results: [(25,)]
# PASS
#
# Question 3
# Which country has the most customers?
# Question: Which country has the most customers?
# ---
# Generated SQL: SELECT Country, COUNT(*) AS CustomerCount
# FROM Customer
# GROUP BY Country
# ORDER BY CustomerCount DESC
# LIMIT 1;
# ---
# Results: [('USA', 13)]
# PASS
#
# Question 4
# Which artist has released the most albums?
# Question: Which artist has released the most albums?
# ---
# Generated SQL: SELECT Artist.Name, COUNT(Album.AlbumId) AS AlbumCount
# FROM Artist
# JOIN Album ON Artist.ArtistId = Album.ArtistId
# GROUP BY Artist.ArtistId
# ORDER BY AlbumCount DESC
# LIMIT 1;
# ---
# Results: [('Iron Maiden', 21)]
# PASS
#
# Question 5
# How many invoices are in the database?
# Question: How many invoices are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Invoice;
# ---
# Results: [(412,)]
# PASS
#
# Question 6
# What are the five longest tracks?
# Question: What are the five longest tracks?
# ---
# Generated SQL: SELECT Name, Milliseconds
# FROM Track
# ORDER BY Milliseconds DESC
# LIMIT 5;
# ---
# Results: [('Occupation / Precipice', 5286953), ('Through a Looking Glass', 5088838), ('Greetings from Earth, Pt. 1', 2960293), ('The Man With Nine Lives', 2956998), ('Battlestar Galactica, Pt. 2', 2956081)]
# PASS
#
# Question 7
# How many employees are in the database?
# Question: How many employees are in the database?
# ---
# Generated SQL: SELECT COUNT(*) FROM Employee;
# ---
# Results: [(8,)]
# PASS
#
# Question 8
# List all customers who live in Brazil.
# Question: List all customers who live in Brazil.
# ---
# Generated SQL: SELECT * FROM Customer WHERE Country = 'Brazil';
# ---
# Results: [(1, 'Luís', 'Gonçalves', 'Embraer - Empresa Brasileira de Aeronáutica S.A.', 'Av. Brigadeiro Faria Lima, 2170', 'São José dos Campos', 'SP', 'Brazil', '12227-000', '+55 (12) 3923-5555', '+55 (12) 3923-5566', 'luisg@embraer.com.br', 3), (10, 'Eduardo', 'Martins', 'Woodstock Discos', 'Rua Dr. Falcão Filho, 155', 'São Paulo', 'SP', 'Brazil', '01007-010', '+55 (11) 3033-5446', '+55 (11) 3033-4564', 'eduardo@woodstock.com.br', 4), (11, 'Alexandre', 'Rocha', 'Banco do Brasil S.A.', 'Av. Paulista, 2022', 'São Paulo', 'SP', 'Brazil', '01310-200', '+55 (11) 3055-3278', '+55 (11) 3055-8131', 'alero@uol.com.br', 5), (12, 'Roberto', 'Almeida', 'Riotur', 'Praça Pio X, 119', 'Rio de Janeiro', 'RJ', 'Brazil', '20040-020', '+55 (21) 2271-7000', '+55 (21) 2271-7070', 'roberto.almeida@riotur.gov.br', 3), (13, 'Fernanda', 'Ramos', None, 'Qe 7 Bloco G', 'Brasília', 'DF', 'Brazil', '71020-677', '+55 (61) 3363-5547', '+55 (61) 3363-7855', 'fernadaramos4@uol.com.br', 4)]
# PASS
#
# Question 9
# Which employee supports the most customers?
# Question: Which employee supports the most customers?
# ---
# Generated SQL: SELECT e.EmployeeId, e.FirstName, e.LastName, COUNT(c.CustomerId) AS CustomerCount
# FROM Employee e
# LEFT JOIN Customer c ON e.EmployeeId = c.SupportRepId
# GROUP BY e.EmployeeId
# ORDER BY CustomerCount DESC
# LIMIT 1;
# ---
# Results: [(3, 'Jane', 'Peacock', 21)]
# FAIL
# Expected: Jane Peacock
# Returned: [(3, 'Jane', 'Peacock', 21)]
#
# Question 10
# Which customer has spent the most money?
# Question: Which customer has spent the most money?
# ---
# Generated SQL: SELECT CustomerId, SUM(Total) AS TotalSpent
# FROM Invoice
# GROUP BY CustomerId
# ORDER BY TotalSpent DESC
# LIMIT 1;
# ---
# Results: [(6, 49.620000000000005)]
# PASS
#
# Question 11
# Which music genre has generated the highest revenue?
# Question: Which music genre has generated the highest revenue?
# ---
# Generated SQL: SELECT g.Name, SUM(il.UnitPrice * il.Quantity) AS Revenue
# FROM Genre g
# JOIN Track t ON g.GenreId = t.GenreId
# JOIN InvoiceLine il ON t.TrackId = il.TrackId
# JOIN Invoice i ON il.InvoiceId = i.InvoiceId
# GROUP BY g.GenreId
# ORDER BY Revenue DESC
# LIMIT 1;
# ---
# Results: [('Rock', 826.6500000000061)]
# PASS
#
# Question 12
# What is the average invoice total?
# Question: What is the average invoice total?
# ---
# Generated SQL: SELECT AVG(Total) AS AverageInvoiceTotal FROM Invoice;
# ---
# Results: [(5.651941747572825,)]
# PASS
#
# Question 13
# Which billing country generated the highest sales?
# Question: Which billing country generated the highest sales?
# ---
# Generated SQL: SELECT BillingCountry, SUM(Total) AS TotalSales
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY TotalSales DESC
# LIMIT 1;
# ---
# Results: [('USA', 523.0600000000003)]
# PASS
#
# Question 14
# Which playlist contains the most tracks?
# Question: Which playlist contains the most tracks?
# ---
# Generated SQL: SELECT PlaylistId, COUNT(TrackId) AS TrackCount
# FROM PlaylistTrack
# GROUP BY PlaylistId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [(1, 3290)]
# PASS
#
# Question 15
# Which media type contains the most tracks?
# Question: Which media type contains the most tracks?
# ---
# Generated SQL: SELECT MediaTypeId, COUNT(*) AS TrackCount
# FROM Track
# GROUP BY MediaTypeId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [(1, 3034)]
# PASS
#
# Question 16
# Which artist has the most tracks?
# Question: Which artist has the most tracks?
# ---
# Generated SQL: SELECT a.Name, COUNT(t.TrackId) AS TrackCount
# FROM Artist a
# JOIN Album al ON a.ArtistId = al.ArtistId
# JOIN Track t ON al.AlbumId = t.AlbumId
# GROUP BY a.ArtistId
# ORDER BY TrackCount DESC
# LIMIT 1;
# ---
# Results: [('Iron Maiden', 213)]
# PASS
#
# Question 17
# How many customers have never placed an order?
# Question: How many customers have never placed an order?
# ---
# Generated SQL: SELECT COUNT(*) AS CustomersWithoutOrders
# FROM Customer
# WHERE CustomerId NOT IN (SELECT DISTINCT CustomerId FROM Invoice);
# ---
# Results: [(0,)]
# PASS
#
# Question 18
# Which country has the highest average invoice total?
# Question: Which country has the highest average invoice total?
# ---
# Generated SQL: SELECT BillingCountry, AVG(Total) AS AverageTotal
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY AverageTotal DESC
# LIMIT 1;
# ---
# Results: [('Chile', 6.659999999999999)]
# PASS
#
# Question 19
# What are the top five countries by total sales revenue?
# Question: What are the top five countries by total sales revenue?
# ---
# Generated SQL: SELECT BillingCountry, SUM(Total) AS TotalRevenue
# FROM Invoice
# GROUP BY BillingCountry
# ORDER BY TotalRevenue DESC
# LIMIT 5;
# ---
# Results: [('USA', 523.0600000000003), ('Canada', 303.9599999999999), ('France', 195.09999999999994), ('Brazil', 190.09999999999997), ('Germany', 156.48)]
# PASS
#
# Question 20
# Which customer placed the largest single order?
# Question: Which customer placed the largest single order?
# ---
# Generated SQL: SELECT Customer.FirstName, Customer.LastName, Invoice.InvoiceId, Invoice.Total
# FROM Customer
# JOIN Invoice ON Customer.CustomerId = Invoice.CustomerId
# ORDER BY Invoice.Total DESC
# LIMIT 1;
# ---
# Results: [('Helena', 'Holý', 404, 25.86)]
# PASS
#
# ======================================================================
# Correct Answers : 19/20
# Accuracy        : 95.00%
# ======================================================================
